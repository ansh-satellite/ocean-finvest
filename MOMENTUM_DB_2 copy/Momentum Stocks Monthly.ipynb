# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    username: str,
    password: str,
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    # Initialize connection
    td_hist = TD_hist(username, password)

    df_list = []
    error_list = []

    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
from pathlib import Path

import os

def run_momentum_strategy(universe_file: str,
                          start_date: str,
                          end_date: str,
                          top_n: int,
                          output_root: str = "Momentum_Results") -> str:
    """
    Run rolling-window momentum strategy on given stock universe.

    Parameters
    ----------
    universe_file : str
        Path to universe file (.csv or .xlsx) with columns ["Symbol", "ISIN Code"].
    start_date : str
        Start date for backtest (YYYY-MM-DD).
    end_date : str
        End date for backtest (YYYY-MM-DD).
    top_n : int
        Number of top ranked stocks to select each window.
    output_root : str
        Root folder where results will be saved.

    Returns
    -------
    str
        Path to master summary file.
    """


    # ==== 1. Load Universe ====
    if universe_file.endswith(".csv"):
        stock_list = pd.read_csv(universe_file)[["Symbol", "ISIN Code"]]
    else:
        stock_list = pd.read_excel(universe_file)[["Symbol", "ISIN Code"]]
    # username = 'tdwsf695'
    # password = 'ocean@695'
    
    username = 'tdwsf695'
    password = 'ocean@695'
    # username = 'td105'
    # password = 'sharma@105'
    # stock_list["Ticker"] = stock_list["Symbol"] + ".NS"
    stock_list["Ticker"] = stock_list["Symbol"] 
    symbol_list = stock_list["Symbol"].tolist()
    universe_name = Path(universe_file).stem
    output_dir = os.path.join(output_root, f"{universe_name}_{top_n}_stocks_results")
    os.makedirs(output_dir, exist_ok=True)

    # ==== 2. Download Data ====
    total_start = pd.to_datetime(start_date)
    total_end = pd.to_datetime(end_date)

    print(f"\n📥 Downloading price data for {len(symbol_list)} symbols...")
    # data = yf.download(symbol_list, start=total_start.strftime('%Y-%m-%d'),
    #                    end=total_end.strftime('%Y-%m-%d'), progress=True)
    # prices_all = data["Close"]
    # prices_all.index = pd.to_datetime(prices_all.index)
    # print("✅ Download complete.")

    data, errors = fetch_truedata_history(username, password, symbol_list, duration='10 Y', bar_size='EOD')
    data = data[['Date', 'Close', 'Ticker']]
    data.drop_duplicates(subset=['Date', 'Ticker'], inplace=True)
    print(data)
    print("Failed tickers:", errors)
    prices = data.pivot(index="Date", columns="Ticker", values="Close")  
    # optional: sort by date
    prices_all = prices.sort_index()



    # ==== 3. Create Rolling Windows ====
    windows = []
    current_start = total_start
    while True:
        current_end = current_start + relativedelta(months=6)
        if current_end > total_end:
            break
        window_prices = prices_all.loc[(prices_all.index >= current_start) & (prices_all.index < current_end)].copy()
        if not window_prices.empty:
            windows.append((current_start, current_end, window_prices))
        current_start += relativedelta(months=1)

    print(f"📊 Created {len(windows)} rolling windows.")

    # ==== 4. Process Each Window ====
    for start, end, prices in windows:
        file_suffix = f"{start.strftime('%Y%m%d')}_{end.strftime('%Y%m%d')}"
        print(f"\n🔍 Processing window: {start.date()} → {end.date()}")

        prices.dropna(axis=1, how='all', inplace=True)
        if prices.empty:
            print("⚠️ All price data missing. Skipping window.")
            continue

        # Monthly momentum
        monthclose = prices.groupby(prices.index.strftime('%Y-%m')).tail(1)
        monthstart = prices.groupby(prices.index.strftime('%Y-%m')).head(1)
        monthstart.index = monthclose.index
        monchange = (monthclose - monthstart) / monthstart
        MOM = (monchange + 1).product() - 1
        mom = MOM * 100

        # Daily returns
        daily_ret = prices.pct_change(fill_method=None)
        positivechange = (daily_ret[daily_ret > 0].count() / daily_ret.count()) * 100
        negativechange = (daily_ret[daily_ret < 0].count() / daily_ret.count()) * 100

        result = pd.concat([positivechange, negativechange, mom], axis=1, join='inner')
        result.columns = ["Positive", "Negative", "Momentum"]
        result = result.reset_index().rename(columns={'index': 'Ticker'})

        # Merge ISIN
        result = pd.merge(result, stock_list[["Ticker", "ISIN Code"]], on="Ticker", how="left")

        # Ranking
        df = result.copy()
        df["Rank_Mom"] = df["Momentum"].rank(method='min', ascending=False)
        print('rank df:', df)
        df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'] if row['Momentum'] > 0 else np.nan, axis=1)
        # df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'])

        df.dropna(inplace=True)
        df["FIP_rank"] = df["FIP"].rank(method="first", ascending=True)
        df["Combined_Rank"] = df["Rank_Mom"] + df["FIP_rank"]
        if end.strftime('%Y-%m-%d') == '2026-01-01':
            df = df[~(df['Ticker'].isin(['MARUTI', 'PTCIL']))]

        df = df.sort_values(by="Combined_Rank", ascending=True).head(top_n)
        last_close = prices.iloc[-1]  # Series: Ticker -> last close price
        df["CMP"] = df["Ticker"].map(last_close)
        before_filter = len(df)
        df = df[df["CMP"] <= 7500].copy()
        filtered_out = before_filter - len(df)
        if filtered_out > 0:
            print(f"🚫 Filtered out {filtered_out} stock(s) with CMP > ₹7,500")
        df["Real_Rank"] = range(1, len(df) + 1)
        df["End_Date"] = end.strftime('%Y-%m-%d')


        # Save each window
        output_file = os.path.join(output_dir, f"momentum_{file_suffix}.xlsx")
        df.to_excel(output_file, index=False)
        print(f"✅ Saved results to: {output_file}")

    # ==== 5. Master File ====
    print("\n📂 Creating master summary file...")
    master_data = []
    for file in os.listdir(output_dir):
        if file.startswith("momentum_") and file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(output_dir, file))
            selected_df = df[["End_Date", "ISIN Code", "Ticker", 'Real_Rank']].copy()
            master_data.append(selected_df)

    if master_data:
        master_df = pd.concat(master_data, ignore_index=True)
        master_file_path = os.path.join(output_dir, "master_momentum_summary.xlsx")
        master_df.to_excel(master_file_path, index=False)
        print(f"✅ Master file saved to: {master_file_path}")
        return master_file_path
    else:
        print("⚠️ No window files found, master not created.")
        return None

# %%
# Momentum/Automating Momentum/Universe/Nifty_500_2025_Apr.csv
# "C:\Users\Admin\Momentum\Automating Momentum\Universe\Nifty_500_2025_Apr.csv"
master_file = run_momentum_strategy(
    universe_file=r"C:\Users\LENOVO\Desktop\Ocean Finvest\MOMENTUM_DB_2 copy\Universe\Nifty_500_2025_Apr.csv",
    start_date="2022-06-01",
    end_date="2026-04-01",
    top_n=20,
    output_root="Stocks"
)
print("Master summary located at:", master_file)
# Out:
# 📥 Downloading price data for 503 symbols...
# (2026-04-28 09:29:15,480) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:6520 Thread:15640)
# 2026-04-28 09:29:15,480 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-04-28 09:29:16,527 - INFO - Fetched data for 360ONE (1639 rows).
# 2026-04-28 09:29:17,569 - INFO - Fetched data for 3MINDIA (2477 rows).
# 2026-04-28 09:29:19,386 - INFO - Fetched data for ABB (2477 rows).
# 2026-04-28 09:29:19,992 - INFO - Fetched data for ACC (2477 rows).
# 2026-04-28 09:29:20,419 - INFO - Fetched data for ACMESOLAR (359 rows).
# 2026-04-28 09:29:20,931 - INFO - Fetched data for AIAENG (2477 rows).
# 2026-04-28 09:29:21,441 - INFO - Fetched data for APLAPOLLO (2477 rows).
# 2026-04-28 09:29:21,948 - INFO - Fetched data for AUBANK (2181 rows).
# 2026-04-28 09:29:22,402 - INFO - Fetched data for AWL (1045 rows).
# 2026-04-28 09:29:23,164 - INFO - Fetched data for AADHARHFC (484 rows).
# 2026-04-28 09:29:23,662 - INFO - Fetched data for AARTIIND (2477 rows).
# 2026-04-28 09:29:24,152 - INFO - Fetched data for AAVAS (1872 rows).
# 2026-04-28 09:29:24,654 - INFO - Fetched data for ABBOTINDIA (2477 rows).
# 2026-04-28 09:29:25,182 - INFO - Fetched data for ACE (2477 rows).
# 2026-04-28 09:29:25,637 - INFO - Fetched data for ADANIENSOL (663 rows).
# 2026-04-28 09:29:26,196 - INFO - Fetched data for ADANIENT (2477 rows).
# 2026-04-28 09:29:26,687 - INFO - Fetched data for ADANIGREEN (1947 rows).
# 2026-04-28 09:29:27,212 - INFO - Fetched data for ADANIPORTS (2477 rows).
# 2026-04-28 09:29:27,733 - INFO - Fetched data for ADANIPOWER (2477 rows).
# 2026-04-28 09:29:28,189 - INFO - Fetched data for ATGL (1852 rows).
# 2026-04-28 09:29:28,667 - INFO - Fetched data for ABCAPITAL (2144 rows).
# 2026-04-28 09:29:29,207 - INFO - Fetched data for ABFRL (2477 rows).
# 2026-04-28 09:29:29,702 - INFO - Fetched data for ABREL (2477 rows).
# 2026-04-28 09:29:30,249 - INFO - Fetched data for ABSLAMC (1127 rows).
# 2026-04-28 09:29:30,767 - INFO - Fetched data for AEGISLOG (2477 rows).
# 2026-04-28 09:29:31,366 - INFO - Fetched data for AFCONS (366 rows).
# 2026-04-28 09:29:31,921 - INFO - Fetched data for AFFLE (1665 rows).
# 2026-04-28 09:29:32,462 - INFO - Fetched data for AJANTPHARM (2477 rows).
# 2026-04-28 09:29:32,902 - INFO - Fetched data for AKUMS (428 rows).
# 2026-04-28 09:29:33,453 - INFO - Fetched data for APLLTD (2477 rows).
# 2026-04-28 09:29:34,133 - INFO - Fetched data for ALIVUS (1171 rows).
# 2026-04-28 09:29:34,671 - INFO - Fetched data for ALKEM (2477 rows).
# 2026-04-28 09:29:35,186 - INFO - Fetched data for ALKYLAMINE (2477 rows).
# 2026-04-28 09:29:36,050 - INFO - Fetched data for ALOKINDS (1534 rows).
# 2026-04-28 09:29:36,568 - INFO - Fetched data for ARE&M (620 rows).
# 2026-04-28 09:29:37,218 - INFO - Fetched data for AMBER (2041 rows).
# 2026-04-28 09:29:38,169 - INFO - Fetched data for AMBUJACEM (2477 rows).
# 2026-04-28 09:29:38,934 - INFO - Fetched data for ANANDRATHI (1084 rows).
# 2026-04-28 09:29:39,511 - INFO - Fetched data for ANANTRAJ (2477 rows).
# 2026-04-28 09:29:40,079 - INFO - Fetched data for ANGELONE (1379 rows).
# 2026-04-28 09:29:40,660 - INFO - Fetched data for APARINDS (2477 rows).
# 2026-04-28 09:29:41,227 - INFO - Fetched data for APOLLOHOSP (2477 rows).
# 2026-04-28 09:29:41,761 - INFO - Fetched data for APOLLOTYRE (2477 rows).
# 2026-04-28 09:29:42,278 - INFO - Fetched data for APTUS (1160 rows).
# 2026-04-28 09:29:42,831 - INFO - Fetched data for ASAHIINDIA (2477 rows).
# 2026-04-28 09:29:43,362 - INFO - Fetched data for ASHOKLEY (2477 rows).
# 2026-04-28 09:29:43,879 - INFO - Fetched data for ASIANPAINT (2477 rows).
# 2026-04-28 09:29:44,377 - INFO - Fetched data for ASTERDM (2023 rows).
# 2026-04-28 09:29:44,915 - INFO - Fetched data for ASTRAZEN (2477 rows).
# 2026-04-28 09:29:45,431 - INFO - Fetched data for ASTRAL (2477 rows).
# 2026-04-28 09:29:45,952 - INFO - Fetched data for ATUL (2477 rows).
# 2026-04-28 09:29:46,558 - INFO - Fetched data for AUROPHARMA (2477 rows).
# 2026-04-28 09:29:47,923 - INFO - Fetched data for AIIL (500 rows).
# 2026-04-28 09:29:48,965 - INFO - Fetched data for DMART (2256 rows).
# 2026-04-28 09:29:49,694 - INFO - Fetched data for AXISBANK (2477 rows).
# 2026-04-28 09:29:50,779 - INFO - Fetched data for BASF (2477 rows).
# 2026-04-28 09:29:51,422 - INFO - Fetched data for BEML (2477 rows).
# 2026-04-28 09:29:52,219 - INFO - Fetched data for BLS (2445 rows).
# 2026-04-28 09:29:53,288 - INFO - Fetched data for BSE (2286 rows).
# 2026-04-28 09:29:54,112 - INFO - Fetched data for BAJAJ-AUTO (2477 rows).
# 2026-04-28 09:29:54,917 - INFO - Fetched data for BAJFINANCE (2477 rows).
# 2026-04-28 09:29:55,598 - INFO - Fetched data for BAJAJFINSV (2477 rows).
# 2026-04-28 09:29:56,543 - INFO - Fetched data for BAJAJHLDNG (2477 rows).
# 2026-04-28 09:29:57,775 - INFO - Fetched data for BAJAJHFL (400 rows).
# 2026-04-28 09:29:58,460 - INFO - Fetched data for BALKRISIND (2477 rows).
# 2026-04-28 09:29:59,146 - INFO - Fetched data for BALRAMCHIN (2477 rows).
# 2026-04-28 09:29:59,786 - INFO - Fetched data for BANDHANBNK (2003 rows).
# 2026-04-28 09:30:00,455 - INFO - Fetched data for BANKBARODA (2477 rows).
# 2026-04-28 09:30:01,211 - INFO - Fetched data for BANKINDIA (2477 rows).
# 2026-04-28 09:30:02,245 - INFO - Fetched data for MAHABANK (2477 rows).
# 2026-04-28 09:30:03,232 - INFO - Fetched data for BATAINDIA (2477 rows).
# 2026-04-28 09:30:04,113 - INFO - Fetched data for BAYERCROP (2477 rows).
# 2026-04-28 09:30:04,866 - INFO - Fetched data for BERGEPAINT (2477 rows).
# 2026-04-28 09:30:05,646 - INFO - Fetched data for BDL (2005 rows).
# 2026-04-28 09:30:06,597 - INFO - Fetched data for BEL (2477 rows).
# 2026-04-28 09:30:07,369 - INFO - Fetched data for BHARATFORG (2477 rows).
# 2026-04-28 09:30:08,308 - INFO - Fetched data for BHEL (2477 rows).
# 2026-04-28 09:30:09,223 - INFO - Fetched data for BPCL (2477 rows).
# 2026-04-28 09:30:10,603 - INFO - Fetched data for BHARTIARTL (2477 rows).
# 2026-04-28 09:30:11,423 - INFO - Fetched data for BHARTIHEXA (506 rows).
# 2026-04-28 09:30:12,086 - INFO - Fetched data for BIKAJI (855 rows).
# 2026-04-28 09:30:12,810 - INFO - Fetched data for BIOCON (2477 rows).
# 2026-04-28 09:30:13,951 - INFO - Fetched data for BSOFT (2477 rows).
# 2026-04-28 09:30:14,853 - INFO - Fetched data for BLUEDART (2477 rows).
# 2026-04-28 09:30:15,635 - INFO - Fetched data for BLUESTARCO (2477 rows).
# 2026-04-28 09:30:16,398 - INFO - Fetched data for BBTC (2477 rows).
# 2026-04-28 09:30:17,036 - INFO - Fetched data for BOSCHLTD (2477 rows).
# 2026-04-28 09:30:17,622 - INFO - Fetched data for FIRSTCRY (423 rows).
# 2026-04-28 09:30:18,257 - INFO - Fetched data for BRIGADE (2477 rows).
# 2026-04-28 09:30:19,008 - INFO - Fetched data for BRITANNIA (2477 rows).
# 2026-04-28 09:30:19,778 - INFO - Fetched data for MAPMYINDIA (1079 rows).
# 2026-04-28 09:30:20,364 - INFO - Fetched data for CCL (2477 rows).
# 2026-04-28 09:30:21,044 - INFO - Fetched data for CESC (2477 rows).
# 2026-04-28 09:30:21,632 - INFO - Fetched data for CGPOWER (2477 rows).
# 2026-04-28 09:30:22,533 - INFO - Fetched data for CRISIL (2477 rows).
# 2026-04-28 09:30:23,279 - INFO - Fetched data for CAMPUS (986 rows).
# 2026-04-28 09:30:24,115 - INFO - Fetched data for CANFINHOME (2477 rows).
# 2026-04-28 09:30:24,752 - INFO - Fetched data for CANBK (2477 rows).
# 2026-04-28 09:30:25,652 - INFO - Fetched data for CAPLIPOINT (2477 rows).
# 2026-04-28 09:30:26,230 - INFO - Fetched data for CGCL (2477 rows).
# 2026-04-28 09:30:26,888 - INFO - Fetched data for CARBORUNIV (2477 rows).
# 2026-04-28 09:30:27,478 - INFO - Fetched data for CASTROLIND (2477 rows).
# 2026-04-28 09:30:28,082 - INFO - Fetched data for CEATLTD (2477 rows).
# 2026-04-28 09:30:28,684 - INFO - Fetched data for CENTRALBK (2477 rows).
# 2026-04-28 09:30:29,667 - INFO - Fetched data for CDSL (2187 rows).
# 2026-04-28 09:30:30,243 - INFO - Fetched data for CENTURYPLY (2477 rows).
# 2026-04-28 09:30:30,820 - INFO - Fetched data for CERA (2477 rows).
# 2026-04-28 09:30:31,425 - INFO - Fetched data for CHALET (1788 rows).
# 2026-04-28 09:30:32,013 - INFO - Fetched data for CHAMBLFERT (2477 rows).
# 2026-04-28 09:30:32,593 - INFO - Fetched data for CHENNPETRO (2477 rows).
# 2026-04-28 09:30:33,257 - INFO - Fetched data for CHOLAHLDNG (2128 rows).
# 2026-04-28 09:30:34,103 - INFO - Fetched data for CHOLAFIN (2477 rows).
# 2026-04-28 09:30:34,815 - INFO - Fetched data for CIPLA (2477 rows).
# 2026-04-28 09:30:35,553 - INFO - Fetched data for CUB (2477 rows).
# 2026-04-28 09:30:36,133 - INFO - Fetched data for CLEAN (1183 rows).
# 2026-04-28 09:30:36,816 - INFO - Fetched data for COALINDIA (2477 rows).
# 2026-04-28 09:30:37,520 - INFO - Fetched data for COCHINSHIP (2157 rows).
# 2026-04-28 09:30:38,159 - INFO - Fetched data for COFORGE (2477 rows).
# 2026-04-28 09:30:38,728 - INFO - Fetched data for COHANCE (1522 rows).
# 2026-04-28 09:30:39,266 - INFO - Fetched data for COLPAL (2477 rows).
# 2026-04-28 09:30:39,712 - INFO - Fetched data for CAMS (1380 rows).
# 2026-04-28 09:30:40,251 - INFO - Fetched data for CONCORDBIO (667 rows).
# 2026-04-28 09:30:40,816 - INFO - Fetched data for CONCOR (2477 rows).
# 2026-04-28 09:30:41,352 - INFO - Fetched data for COROMANDEL (2477 rows).
# 2026-04-28 09:30:41,847 - INFO - Fetched data for CRAFTSMAN (1260 rows).
# 2026-04-28 09:30:42,362 - INFO - Fetched data for CREDITACC (1901 rows).
# 2026-04-28 09:30:42,970 - INFO - Fetched data for CROMPTON (2468 rows).
# 2026-04-28 09:30:43,462 - INFO - Fetched data for CUMMINSIND (2477 rows).
# 2026-04-28 09:30:43,963 - INFO - Fetched data for CYIENT (2477 rows).
# 2026-04-28 09:30:44,484 - INFO - Fetched data for DCMSHRIRAM (2477 rows).
# 2026-04-28 09:30:44,981 - INFO - Fetched data for DLF (2477 rows).
# 2026-04-28 09:30:45,412 - INFO - Fetched data for DOMS (583 rows).
# 2026-04-28 09:30:45,915 - INFO - Fetched data for DABUR (2477 rows).
# 2026-04-28 09:30:46,380 - INFO - Fetched data for DALBHARAT (1800 rows).
# 2026-04-28 09:30:46,853 - INFO - Fetched data for DATAPATTNS (1076 rows).
# 2026-04-28 09:30:47,352 - INFO - Fetched data for DEEPAKFERT (2477 rows).
# 2026-04-28 09:30:47,888 - INFO - Fetched data for DEEPAKNTR (2477 rows).
# 2026-04-28 09:30:48,357 - INFO - Fetched data for DELHIVERY (975 rows).
# 2026-04-28 09:30:48,812 - INFO - Fetched data for DEVYANI (1165 rows).
# 2026-04-28 09:30:49,307 - INFO - Fetched data for DIVISLAB (2477 rows).
# 2026-04-28 09:30:49,827 - INFO - Fetched data for DIXON (2133 rows).
# 2026-04-28 09:30:50,351 - INFO - Fetched data for LALPATHLAB (2477 rows).
# 2026-04-28 09:30:50,846 - INFO - Fetched data for DRREDDY (2477 rows).
# (2026-04-28 09:30:51,266) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:6520 Thread:15640)
# 2026-04-28 09:30:51,266 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-04-28 09:30:51,268 - ERROR - Failed to fetch data for DUMMYABFRL: 'NoneType' object does not support item assignment
# (2026-04-28 09:30:51,566) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:6520 Thread:15640)
# 2026-04-28 09:30:51,566 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-04-28 09:30:51,568 - ERROR - Failed to fetch data for DUMMYSIEMS: 'NoneType' object does not support item assignment
# (2026-04-28 09:30:51,902) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:6520 Thread:15640)
# 2026-04-28 09:30:51,902 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-04-28 09:30:51,904 - ERROR - Failed to fetch data for DUMMYRAYMN: 'NoneType' object does not support item assignment
# 2026-04-28 09:30:52,305 - INFO - Fetched data for EIDPARRY (2477 rows).
# 2026-04-28 09:30:52,806 - INFO - Fetched data for EIHOTEL (2477 rows).
# 2026-04-28 09:30:53,304 - INFO - Fetched data for EICHERMOT (2477 rows).
# 2026-04-28 09:30:53,782 - INFO - Fetched data for ELECON (2477 rows).
# 2026-04-28 09:30:54,312 - INFO - Fetched data for ELGIEQUIP (2477 rows).
# 2026-04-28 09:30:54,832 - INFO - Fetched data for EMAMILTD (2477 rows).
# 2026-04-28 09:30:55,265 - INFO - Fetched data for EMCURE (446 rows).
# 2026-04-28 09:30:55,756 - INFO - Fetched data for ENDURANCE (2361 rows).
# 2026-04-28 09:30:56,250 - INFO - Fetched data for ENGINERSIN (2477 rows).
# 2026-04-28 09:30:56,743 - INFO - Fetched data for ERIS (2188 rows).
# 2026-04-28 09:30:57,236 - INFO - Fetched data for ESCORTS (2477 rows).
# 2026-04-28 09:30:57,688 - INFO - Fetched data for ETERNAL (1180 rows).
# 2026-04-28 09:30:58,177 - INFO - Fetched data for EXIDEIND (2477 rows).
# 2026-04-28 09:30:58,615 - INFO - Fetched data for NYKAA (1107 rows).
# 2026-04-28 09:30:59,132 - INFO - Fetched data for FEDERALBNK (2477 rows).
# 2026-04-28 09:30:59,617 - INFO - Fetched data for FACT (2477 rows).
# 2026-04-28 09:31:00,184 - INFO - Fetched data for FINCABLES (2477 rows).
# 2026-04-28 09:31:00,666 - INFO - Fetched data for FINPIPE (2477 rows).
# 2026-04-28 09:31:01,181 - INFO - Fetched data for FSL (2477 rows).
# 2026-04-28 09:31:01,815 - INFO - Fetched data for FIVESTAR (852 rows).
# 2026-04-28 09:31:02,344 - INFO - Fetched data for FORTIS (2477 rows).
# 2026-04-28 09:31:02,829 - INFO - Fetched data for GAIL (2477 rows).
# 2026-04-28 09:31:03,356 - INFO - Fetched data for GVT&D (2477 rows).
# 2026-04-28 09:31:03,905 - INFO - Fetched data for GMRAIRPORT (2477 rows).
# 2026-04-28 09:31:04,381 - INFO - Fetched data for GRSE (1870 rows).
# 2026-04-28 09:31:04,878 - INFO - Fetched data for GICRE (2108 rows).
# 2026-04-28 09:31:05,372 - INFO - Fetched data for GILLETTE (2477 rows).
# 2026-04-28 09:31:05,832 - INFO - Fetched data for GLAND (1345 rows).
# 2026-04-28 09:31:06,334 - INFO - Fetched data for GLAXO (2477 rows).
# 2026-04-28 09:31:06,871 - INFO - Fetched data for GLENMARK (2477 rows).
# 2026-04-28 09:31:07,601 - INFO - Fetched data for MEDANTA (855 rows).
# 2026-04-28 09:31:08,012 - INFO - Fetched data for GODIGIT (479 rows).
# 2026-04-28 09:31:08,537 - INFO - Fetched data for GPIL (2477 rows).
# 2026-04-28 09:31:09,022 - INFO - Fetched data for GODFRYPHLP (2477 rows).
# 2026-04-28 09:31:09,500 - INFO - Fetched data for GODREJAGRO (2114 rows).
# 2026-04-28 09:31:09,992 - INFO - Fetched data for GODREJCP (2477 rows).
# 2026-04-28 09:31:10,490 - INFO - Fetched data for GODREJIND (2477 rows).
# 2026-04-28 09:31:11,038 - INFO - Fetched data for GODREJPROP (2477 rows).
# 2026-04-28 09:31:11,522 - INFO - Fetched data for GRANULES (2477 rows).
# 2026-04-28 09:31:12,050 - INFO - Fetched data for GRAPHITE (2477 rows).
# 2026-04-28 09:31:12,552 - INFO - Fetched data for GRASIM (2477 rows).
# 2026-04-28 09:31:13,033 - INFO - Fetched data for GRAVITA (2477 rows).
# 2026-04-28 09:31:13,521 - INFO - Fetched data for GESHIP (2477 rows).
# 2026-04-28 09:31:13,983 - INFO - Fetched data for FLUOROCHEM (1622 rows).
# 2026-04-28 09:31:14,485 - INFO - Fetched data for GUJGASLTD (2477 rows).
# 2026-04-28 09:31:15,321 - INFO - Fetched data for GMDCLTD (2477 rows).
# 2026-04-28 09:31:15,804 - INFO - Fetched data for GNFC (2477 rows).
# 2026-04-28 09:31:16,306 - INFO - Fetched data for GPPL (2477 rows).
# 2026-04-28 09:31:16,818 - INFO - Fetched data for GSPL (2477 rows).
# 2026-04-28 09:31:17,334 - INFO - Fetched data for HEG (2477 rows).
# 2026-04-28 09:31:17,830 - INFO - Fetched data for HBLENGINE (2477 rows).
# 2026-04-28 09:31:18,319 - INFO - Fetched data for HCLTECH (2477 rows).
# 2026-04-28 09:31:18,824 - INFO - Fetched data for HDFCAMC (1912 rows).
# 2026-04-28 09:31:19,413 - INFO - Fetched data for HDFCBANK (2477 rows).
# 2026-04-28 09:31:19,897 - INFO - Fetched data for HDFCLIFE (2091 rows).
# 2026-04-28 09:31:20,385 - INFO - Fetched data for HFCL (2477 rows).
# 2026-04-28 09:31:20,843 - INFO - Fetched data for HAPPSTMNDS (1390 rows).
# 2026-04-28 09:31:21,325 - INFO - Fetched data for HAVELLS (2477 rows).
# 2026-04-28 09:31:21,819 - INFO - Fetched data for HEROMOTOCO (2477 rows).
# 2026-04-28 09:31:22,346 - INFO - Fetched data for HSCL (2477 rows).
# 2026-04-28 09:31:22,843 - INFO - Fetched data for HINDALCO (2477 rows).
# 2026-04-28 09:31:23,323 - INFO - Fetched data for HAL (2002 rows).
# 2026-04-28 09:31:24,132 - INFO - Fetched data for HINDCOPPER (2477 rows).
# 2026-04-28 09:31:24,612 - INFO - Fetched data for HINDPETRO (2477 rows).
# 2026-04-28 09:31:25,112 - INFO - Fetched data for HINDUNILVR (2477 rows).
# 2026-04-28 09:31:25,600 - INFO - Fetched data for HINDZINC (2477 rows).
# 2026-04-28 09:31:26,175 - INFO - Fetched data for POWERINDIA (1508 rows).
# 2026-04-28 09:31:26,631 - INFO - Fetched data for HOMEFIRST (1295 rows).
# 2026-04-28 09:31:27,175 - INFO - Fetched data for HONASA (613 rows).
# 2026-04-28 09:31:27,706 - INFO - Fetched data for HONAUT (2477 rows).
# 2026-04-28 09:31:28,195 - INFO - Fetched data for HUDCO (2216 rows).
# 2026-04-28 09:31:28,624 - INFO - Fetched data for HYUNDAI (375 rows).
# 2026-04-28 09:31:29,174 - INFO - Fetched data for ICICIBANK (2477 rows).
# 2026-04-28 09:31:29,654 - INFO - Fetched data for ICICIGI (2126 rows).
# 2026-04-28 09:31:30,164 - INFO - Fetched data for ICICIPRULI (2373 rows).
# 2026-04-28 09:31:30,670 - INFO - Fetched data for IDBI (2477 rows).
# 2026-04-28 09:31:31,242 - INFO - Fetched data for IDFCFIRSTB (2476 rows).
# 2026-04-28 09:31:31,765 - INFO - Fetched data for IFCI (2477 rows).
# 2026-04-28 09:31:32,285 - INFO - Fetched data for IIFL (2477 rows).
# 2026-04-28 09:31:32,750 - INFO - Fetched data for INOXINDIA (582 rows).
# 2026-04-28 09:31:33,378 - INFO - Fetched data for IRB (2477 rows).
# 2026-04-28 09:31:33,895 - INFO - Fetched data for IRCON (1877 rows).
# 2026-04-28 09:31:34,418 - INFO - Fetched data for ITC (2477 rows).
# 2026-04-28 09:31:35,248 - INFO - Fetched data for ITI (2477 rows).
# 2026-04-28 09:31:36,026 - INFO - Fetched data for INDGN (487 rows).
# 2026-04-28 09:31:36,650 - INFO - Fetched data for INDIACEM (2477 rows).
# 2026-04-28 09:31:37,280 - INFO - Fetched data for INDIAMART (1690 rows).
# 2026-04-28 09:31:37,829 - INFO - Fetched data for INDIANB (2477 rows).
# 2026-04-28 09:31:38,321 - INFO - Fetched data for IEX (2110 rows).
# 2026-04-28 09:31:38,844 - INFO - Fetched data for INDHOTEL (2477 rows).
# 2026-04-28 09:31:39,662 - INFO - Fetched data for IOC (2477 rows).
# 2026-04-28 09:31:40,168 - INFO - Fetched data for IOB (2477 rows).
# 2026-04-28 09:31:40,632 - INFO - Fetched data for IRCTC (1624 rows).
# 2026-04-28 09:31:41,081 - INFO - Fetched data for IRFC (1298 rows).
# 2026-04-28 09:31:41,517 - INFO - Fetched data for IREDA (598 rows).
# 2026-04-28 09:31:41,996 - INFO - Fetched data for IGL (2477 rows).
# 2026-04-28 09:31:42,483 - INFO - Fetched data for INDUSTOWER (2477 rows).
# 2026-04-28 09:31:42,979 - INFO - Fetched data for INDUSINDBK (2477 rows).
# 2026-04-28 09:31:43,459 - INFO - Fetched data for NAUKRI (2477 rows).
# 2026-04-28 09:31:43,999 - INFO - Fetched data for INFY (2477 rows).
# 2026-04-28 09:31:44,495 - INFO - Fetched data for INOXWIND (2477 rows).
# 2026-04-28 09:31:44,986 - INFO - Fetched data for INTELLECT (2477 rows).
# 2026-04-28 09:31:45,528 - INFO - Fetched data for INDIGO (2477 rows).
# 2026-04-28 09:31:45,946 - INFO - Fetched data for IGIL (334 rows).
# 2026-04-28 09:31:46,365 - INFO - Fetched data for IKS (335 rows).
# 2026-04-28 09:31:46,859 - INFO - Fetched data for IPCALAB (2477 rows).
# 2026-04-28 09:31:47,372 - INFO - Fetched data for JBCHEPHARM (2477 rows).
# 2026-04-28 09:31:47,878 - INFO - Fetched data for JKCEMENT (2477 rows).
# 2026-04-28 09:31:48,392 - INFO - Fetched data for JBMA (2477 rows).
# 2026-04-28 09:31:48,892 - INFO - Fetched data for JKTYRE (2477 rows).
# 2026-04-28 09:31:49,410 - INFO - Fetched data for JMFINANCIL (2477 rows).
# 2026-04-28 09:31:50,423 - INFO - Fetched data for JSWENERGY (2477 rows).
# 2026-04-28 09:31:50,993 - INFO - Fetched data for JSWHL (2477 rows).
# 2026-04-28 09:31:51,454 - INFO - Fetched data for JSWINFRA (637 rows).
# 2026-04-28 09:31:52,055 - INFO - Fetched data for JSWSTEEL (2477 rows).
# 2026-04-28 09:31:52,582 - INFO - Fetched data for JPPOWER (2477 rows).
# 2026-04-28 09:31:53,091 - INFO - Fetched data for J&KBANK (2477 rows).
# 2026-04-28 09:31:53,612 - INFO - Fetched data for JINDALSAW (2477 rows).
# 2026-04-28 09:31:54,128 - INFO - Fetched data for JSL (2477 rows).
# 2026-04-28 09:31:54,665 - INFO - Fetched data for JINDALSTEL (2477 rows).
# 2026-04-28 09:31:55,184 - INFO - Fetched data for JIOFIN (666 rows).
# 2026-04-28 09:31:55,729 - INFO - Fetched data for JUBLFOOD (2477 rows).
# 2026-04-28 09:31:56,197 - INFO - Fetched data for JUBLINGREA (1264 rows).
# 2026-04-28 09:31:56,675 - INFO - Fetched data for JUBLPHARMA (1289 rows).
# 2026-04-28 09:31:57,404 - INFO - Fetched data for JWL (2477 rows).
# 2026-04-28 09:31:58,022 - INFO - Fetched data for JUSTDIAL (2477 rows).
# 2026-04-28 09:31:58,614 - INFO - Fetched data for JYOTHYLAB (2477 rows).
# 2026-04-28 09:31:59,247 - INFO - Fetched data for JYOTICNC (565 rows).
# 2026-04-28 09:31:59,894 - INFO - Fetched data for KPRMILL (2477 rows).
# 2026-04-28 09:32:00,798 - INFO - Fetched data for KEI (2477 rows).
# 2026-04-28 09:32:01,551 - INFO - Fetched data for KNRCON (2477 rows).
# 2026-04-28 09:32:02,228 - INFO - Fetched data for KPITTECH (1740 rows).
# 2026-04-28 09:32:02,799 - INFO - Fetched data for KAJARIACER (2477 rows).
# 2026-04-28 09:32:03,507 - INFO - Fetched data for KPIL (2477 rows).
# 2026-04-28 09:32:04,207 - INFO - Fetched data for KALYANKJIL (1259 rows).
# 2026-04-28 09:32:04,836 - INFO - Fetched data for KANSAINER (2477 rows).
# 2026-04-28 09:32:05,448 - INFO - Fetched data for KARURVYSYA (2477 rows).
# 2026-04-28 09:32:06,070 - INFO - Fetched data for KAYNES (851 rows).
# 2026-04-28 09:32:06,660 - INFO - Fetched data for KEC (2477 rows).
# 2026-04-28 09:32:07,246 - INFO - Fetched data for KFINTECH (824 rows).
# 2026-04-28 09:32:07,856 - INFO - Fetched data for KIRLOSBROS (2477 rows).
# 2026-04-28 09:32:08,806 - INFO - Fetched data for KIRLOSENG (2477 rows).
# 2026-04-28 09:32:09,403 - INFO - Fetched data for KOTAKBANK (2477 rows).
# 2026-04-28 09:32:10,006 - INFO - Fetched data for KIMS (1198 rows).
# 2026-04-28 09:32:10,650 - INFO - Fetched data for LTF (2477 rows).
# 2026-04-28 09:32:11,252 - INFO - Fetched data for LTTS (2377 rows).
# 2026-04-28 09:32:11,857 - INFO - Fetched data for LICHSGFIN (2477 rows).
# 2026-04-28 09:32:12,372 - INFO - Fetched data for LTFOODS (614 rows).
# 2026-04-28 09:32:12,940 - INFO - Fetched data for LTIM (2382 rows).
# 2026-04-28 09:32:13,561 - INFO - Fetched data for LT (2477 rows).
# 2026-04-28 09:32:14,031 - INFO - Fetched data for LATENTVIEW (1099 rows).
# 2026-04-28 09:32:14,536 - INFO - Fetched data for LAURUSLABS (2319 rows).
# 2026-04-28 09:32:15,038 - INFO - Fetched data for LEMONTREE (1996 rows).
# 2026-04-28 09:32:15,492 - INFO - Fetched data for LICI (980 rows).
# 2026-04-28 09:32:16,074 - INFO - Fetched data for LINDEINDIA (2477 rows).
# 2026-04-28 09:32:16,535 - INFO - Fetched data for LLOYDSME (690 rows).
# 2026-04-28 09:32:17,052 - INFO - Fetched data for LUPIN (2477 rows).
# 2026-04-28 09:32:17,552 - INFO - Fetched data for MMTC (2477 rows).
# 2026-04-28 09:32:18,050 - INFO - Fetched data for MRF (2477 rows).
# 2026-04-28 09:32:18,509 - INFO - Fetched data for LODHA (1246 rows).
# 2026-04-28 09:32:19,016 - INFO - Fetched data for MGL (2433 rows).
# 2026-04-28 09:32:19,600 - INFO - Fetched data for MAHSEAMLES (2477 rows).
# 2026-04-28 09:32:20,095 - INFO - Fetched data for M&MFIN (2477 rows).
# 2026-04-28 09:32:20,685 - INFO - Fetched data for M&M (2477 rows).
# 2026-04-28 09:32:21,232 - INFO - Fetched data for MANAPPURAM (2477 rows).
# 2026-04-28 09:32:21,733 - INFO - Fetched data for MRPL (2477 rows).
# 2026-04-28 09:32:22,178 - INFO - Fetched data for MANKIND (738 rows).
# 2026-04-28 09:32:22,669 - INFO - Fetched data for MARICO (2477 rows).
# 2026-04-28 09:32:23,165 - INFO - Fetched data for MARUTI (2477 rows).
# 2026-04-28 09:32:23,666 - INFO - Fetched data for MASTEK (2477 rows).
# 2026-04-28 09:32:24,176 - INFO - Fetched data for MFSL (2477 rows).
# 2026-04-28 09:32:24,637 - INFO - Fetched data for MAXHEALTH (1409 rows).
# 2026-04-28 09:32:25,094 - INFO - Fetched data for MAZDOCK (1375 rows).
# 2026-04-28 09:32:25,562 - INFO - Fetched data for METROPOLIS (1743 rows).
# 2026-04-28 09:32:26,107 - INFO - Fetched data for MINDACORP (2477 rows).
# 2026-04-28 09:32:26,562 - INFO - Fetched data for MSUMI (1012 rows).
# 2026-04-28 09:32:27,111 - INFO - Fetched data for MOTILALOFS (2477 rows).
# 2026-04-28 09:32:27,611 - INFO - Fetched data for MPHASIS (2477 rows).
# 2026-04-28 09:32:28,094 - INFO - Fetched data for MCX (2477 rows).
# 2026-04-28 09:32:28,577 - INFO - Fetched data for MUTHOOTFIN (2477 rows).
# 2026-04-28 09:32:29,066 - INFO - Fetched data for NATCOPHARM (2477 rows).
# 2026-04-28 09:32:29,560 - INFO - Fetched data for NBCC (2477 rows).
# 2026-04-28 09:32:30,091 - INFO - Fetched data for NCC (2477 rows).
# 2026-04-28 09:32:30,593 - INFO - Fetched data for NHPC (2477 rows).
# 2026-04-28 09:32:31,101 - INFO - Fetched data for NLCINDIA (2477 rows).
# 2026-04-28 09:32:31,622 - INFO - Fetched data for NMDC (2477 rows).
# 2026-04-28 09:32:32,070 - INFO - Fetched data for NSLNISP (787 rows).
# 2026-04-28 09:32:32,485 - INFO - Fetched data for NTPCGREEN (351 rows).
# 2026-04-28 09:32:32,990 - INFO - Fetched data for NTPC (2477 rows).
# 2026-04-28 09:32:33,501 - INFO - Fetched data for NH (2477 rows).
# 2026-04-28 09:32:33,988 - INFO - Fetched data for NATIONALUM (2477 rows).
# 2026-04-28 09:32:34,477 - INFO - Fetched data for NAVA (2477 rows).
# 2026-04-28 09:32:34,969 - INFO - Fetched data for NAVINFLUOR (2477 rows).
# 2026-04-28 09:32:35,517 - INFO - Fetched data for NESTLEIND (2477 rows).
# 2026-04-28 09:32:36,134 - INFO - Fetched data for NETWEB (682 rows).
# 2026-04-28 09:32:36,626 - INFO - Fetched data for NETWORK18 (2477 rows).
# 2026-04-28 09:32:37,161 - INFO - Fetched data for NEULANDLAB (2477 rows).
# 2026-04-28 09:32:37,645 - INFO - Fetched data for NEWGEN (2042 rows).
# 2026-04-28 09:32:38,159 - INFO - Fetched data for NAM-INDIA (2099 rows).
# 2026-04-28 09:32:38,595 - INFO - Fetched data for NIVABUPA (358 rows).
# 2026-04-28 09:32:39,047 - INFO - Fetched data for NUVAMA (640 rows).
# 2026-04-28 09:32:39,602 - INFO - Fetched data for OBEROIRLTY (2477 rows).
# 2026-04-28 09:32:40,292 - INFO - Fetched data for ONGC (2477 rows).
# 2026-04-28 09:32:40,831 - INFO - Fetched data for OIL (2477 rows).
# 2026-04-28 09:32:41,273 - INFO - Fetched data for OLAELEC (425 rows).
# 2026-04-28 09:32:41,783 - INFO - Fetched data for OLECTRA (2477 rows).
# 2026-04-28 09:32:42,240 - INFO - Fetched data for PAYTM (1101 rows).
# 2026-04-28 09:32:42,731 - INFO - Fetched data for OFSS (2477 rows).
# 2026-04-28 09:32:43,238 - INFO - Fetched data for POLICYBZR (1104 rows).
# 2026-04-28 09:32:43,695 - INFO - Fetched data for PCBL (1062 rows).
# 2026-04-28 09:32:44,246 - INFO - Fetched data for PGEL (2477 rows).
# 2026-04-28 09:32:44,746 - INFO - Fetched data for PIIND (2477 rows).
# 2026-04-28 09:32:45,249 - INFO - Fetched data for PNBHOUSING (2348 rows).
# 2026-04-28 09:32:45,744 - INFO - Fetched data for PNCINFRA (2477 rows).
# 2026-04-28 09:32:46,183 - INFO - Fetched data for PTCIL (715 rows).
# 2026-04-28 09:32:46,683 - INFO - Fetched data for PVRINOX (2477 rows).
# 2026-04-28 09:32:47,217 - INFO - Fetched data for PAGEIND (2477 rows).
# 2026-04-28 09:32:47,707 - INFO - Fetched data for PATANJALI (939 rows).
# 2026-04-28 09:32:48,213 - INFO - Fetched data for PERSISTENT (2477 rows).
# 2026-04-28 09:32:48,755 - INFO - Fetched data for PETRONET (2477 rows).
# 2026-04-28 09:32:49,273 - INFO - Fetched data for PFIZER (2477 rows).
# 2026-04-28 09:32:49,752 - INFO - Fetched data for PHOENIXLTD (2477 rows).
# 2026-04-28 09:32:50,260 - INFO - Fetched data for PIDILITIND (2477 rows).
# 2026-04-28 09:32:50,769 - INFO - Fetched data for PEL (2331 rows).
# 2026-04-28 09:32:51,219 - INFO - Fetched data for PPLPHARMA (872 rows).
# 2026-04-28 09:32:51,708 - INFO - Fetched data for POLYMED (2477 rows).
# 2026-04-28 09:32:52,173 - INFO - Fetched data for POLYCAB (1742 rows).
# 2026-04-28 09:32:52,673 - INFO - Fetched data for POONAWALLA (2477 rows).
# 2026-04-28 09:32:53,164 - INFO - Fetched data for PFC (2477 rows).
# 2026-04-28 09:32:53,668 - INFO - Fetched data for POWERGRID (2477 rows).
# 2026-04-28 09:32:54,156 - INFO - Fetched data for PRAJIND (2477 rows).
# 2026-04-28 09:32:54,586 - INFO - Fetched data for PREMIERENE (409 rows).
# 2026-04-28 09:32:55,162 - INFO - Fetched data for PRESTIGE (2477 rows).
# 2026-04-28 09:32:55,687 - INFO - Fetched data for PNB (2477 rows).
# 2026-04-28 09:32:56,137 - INFO - Fetched data for RRKABEL (644 rows).
# 2026-04-28 09:32:56,632 - INFO - Fetched data for RBLBANK (2392 rows).
# 2026-04-28 09:32:57,163 - INFO - Fetched data for RECLTD (2477 rows).
# 2026-04-28 09:32:57,617 - INFO - Fetched data for RHIM (1182 rows).
# 2026-04-28 09:32:58,100 - INFO - Fetched data for RITES (1937 rows).
# 2026-04-28 09:32:58,600 - INFO - Fetched data for RADICO (2477 rows).
# 2026-04-28 09:32:59,062 - INFO - Fetched data for RVNL (1745 rows).
# 2026-04-28 09:32:59,531 - INFO - Fetched data for RAILTEL (1278 rows).
# 2026-04-28 09:33:00,036 - INFO - Fetched data for RAINBOW (984 rows).
# 2026-04-28 09:33:00,554 - INFO - Fetched data for RKFORGE (2477 rows).
# 2026-04-28 09:33:01,083 - INFO - Fetched data for RCF (2477 rows).
# 2026-04-28 09:33:01,531 - INFO - Fetched data for RTNINDIA (1254 rows).
# 2026-04-28 09:33:01,986 - INFO - Fetched data for RAYMONDLSL (407 rows).
# 2026-04-28 09:33:02,499 - INFO - Fetched data for RAYMOND (2477 rows).
# 2026-04-28 09:33:03,006 - INFO - Fetched data for REDINGTON (2477 rows).
# 2026-04-28 09:33:03,511 - INFO - Fetched data for RELIANCE (2477 rows).
# 2026-04-28 09:33:04,118 - INFO - Fetched data for RPOWER (2477 rows).
# 2026-04-28 09:33:04,672 - INFO - Fetched data for ROUTE (1389 rows).
# 2026-04-28 09:33:05,146 - INFO - Fetched data for SBFC (669 rows).
# 2026-04-28 09:33:05,794 - INFO - Fetched data for SBICARD (1518 rows).
# 2026-04-28 09:33:06,603 - INFO - Fetched data for SBILIFE (2123 rows).
# 2026-04-28 09:33:07,220 - INFO - Fetched data for SJVN (2477 rows).
# 2026-04-28 09:33:07,859 - INFO - Fetched data for SKFINDIA (2477 rows).
# 2026-04-28 09:33:08,447 - INFO - Fetched data for SRF (2477 rows).
# 2026-04-28 09:33:09,042 - INFO - Fetched data for SAGILITY (360 rows).
# 2026-04-28 09:33:09,492 - INFO - Fetched data for SAILIFE (336 rows).
# 2026-04-28 09:33:10,091 - INFO - Fetched data for SAMMAANCAP (2477 rows).
# 2026-04-28 09:33:10,858 - INFO - Fetched data for MOTHERSON (2477 rows).
# 2026-04-28 09:33:11,357 - INFO - Fetched data for SAPPHIRE (1101 rows).
# 2026-04-28 09:33:11,954 - INFO - Fetched data for SARDAEN (2477 rows).
# 2026-04-28 09:33:12,508 - INFO - Fetched data for SAREGAMA (2477 rows).
# 2026-04-28 09:33:12,996 - INFO - Fetched data for SCHAEFFLER (2477 rows).
# 2026-04-28 09:33:13,654 - INFO - Fetched data for SCHNEIDER (2477 rows).
# 2026-04-28 09:33:14,231 - INFO - Fetched data for SCI (2477 rows).
# 2026-04-28 09:33:14,813 - INFO - Fetched data for SHREECEM (2477 rows).
# 2026-04-28 09:33:15,438 - INFO - Fetched data for RENUKA (2477 rows).
# 2026-04-28 09:33:16,037 - INFO - Fetched data for SHRIRAMFIN (2477 rows).
# 2026-04-28 09:33:16,517 - INFO - Fetched data for SHYAMMETL (1200 rows).
# 2026-04-28 09:33:17,014 - INFO - Fetched data for SIEMENS (2477 rows).
# 2026-04-28 09:33:17,465 - INFO - Fetched data for SIGNATURE (639 rows).
# 2026-04-28 09:33:17,979 - INFO - Fetched data for SOBHA (2477 rows).
# 2026-04-28 09:33:18,501 - INFO - Fetched data for SOLARINDS (2477 rows).
# 2026-04-28 09:33:18,956 - INFO - Fetched data for SONACOMS (1200 rows).
# 2026-04-28 09:33:19,488 - INFO - Fetched data for SONATSOFTW (2477 rows).
# 2026-04-28 09:33:19,979 - INFO - Fetched data for STARHEALTH (1085 rows).
# 2026-04-28 09:33:20,545 - INFO - Fetched data for SBIN (2477 rows).
# 2026-04-28 09:33:21,237 - INFO - Fetched data for SAIL (2477 rows).
# 2026-04-28 09:33:21,794 - INFO - Fetched data for SWSOLAR (1659 rows).
# 2026-04-28 09:33:22,336 - INFO - Fetched data for SUMICHEM (1551 rows).
# 2026-04-28 09:33:22,884 - INFO - Fetched data for SUNPHARMA (2477 rows).
# 2026-04-28 09:33:23,455 - INFO - Fetched data for SUNTV (2477 rows).
# 2026-04-28 09:33:23,964 - INFO - Fetched data for SUNDARMFIN (2477 rows).
# 2026-04-28 09:33:24,476 - INFO - Fetched data for SUNDRMFAST (2477 rows).
# 2026-04-28 09:33:24,966 - INFO - Fetched data for SUPREMEIND (2477 rows).
# 2026-04-28 09:33:25,459 - INFO - Fetched data for SUZLON (2477 rows).
# (2026-04-28 09:33:25,970) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:6520 Thread:15640)
# 2026-04-28 09:33:25,970 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-04-28 09:33:25,973 - ERROR - Failed to fetch data for SWANENERGY: 'NoneType' object does not support item assignment
# 2026-04-28 09:33:26,314 - INFO - Fetched data for SWIGGY (359 rows).
# 2026-04-28 09:33:26,837 - INFO - Fetched data for SYNGENE (2477 rows).
# 2026-04-28 09:33:27,307 - INFO - Fetched data for SYRMA (909 rows).
# 2026-04-28 09:33:27,756 - INFO - Fetched data for TBOTEK (485 rows).
# 2026-04-28 09:33:28,271 - INFO - Fetched data for TVSMOTOR (2477 rows).
# 2026-04-28 09:33:28,768 - INFO - Fetched data for TANLA (2477 rows).
# 2026-04-28 09:33:29,279 - INFO - Fetched data for TATACHEM (2477 rows).
# 2026-04-28 09:33:29,800 - INFO - Fetched data for TATACOMM (2477 rows).
# 2026-04-28 09:33:30,310 - INFO - Fetched data for TCS (2477 rows).
# 2026-04-28 09:33:30,814 - INFO - Fetched data for TATACONSUM (2476 rows).
# 2026-04-28 09:33:31,317 - INFO - Fetched data for TATAELXSI (2477 rows).
# 2026-04-28 09:33:31,822 - INFO - Fetched data for TATAINVEST (2477 rows).
# (2026-04-28 09:33:32,234) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:6520 Thread:15640)
# 2026-04-28 09:33:32,234 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-04-28 09:33:32,236 - ERROR - Failed to fetch data for TATAMOTORS: 'NoneType' object does not support item assignment
# 2026-04-28 09:33:32,625 - INFO - Fetched data for TATAPOWER (2477 rows).
# 2026-04-28 09:33:33,188 - INFO - Fetched data for TATASTEEL (2477 rows).
# 2026-04-28 09:33:33,610 - INFO - Fetched data for TATATECH (597 rows).
# 2026-04-28 09:33:34,387 - INFO - Fetched data for TTML (2477 rows).
# 2026-04-28 09:33:34,885 - INFO - Fetched data for TECHM (2477 rows).
# 2026-04-28 09:33:35,361 - INFO - Fetched data for TECHNOE (1834 rows).
# 2026-04-28 09:33:35,853 - INFO - Fetched data for TEJASNET (2190 rows).
# 2026-04-28 09:33:36,354 - INFO - Fetched data for NIACL (2095 rows).
# 2026-04-28 09:33:36,839 - INFO - Fetched data for RAMCOCEM (2477 rows).
# 2026-04-28 09:33:37,330 - INFO - Fetched data for THERMAX (2477 rows).
# 2026-04-28 09:33:37,861 - INFO - Fetched data for TIMKEN (2477 rows).
# 2026-04-28 09:33:38,366 - INFO - Fetched data for TITAGARH (2477 rows).
# 2026-04-28 09:33:38,852 - INFO - Fetched data for TITAN (2477 rows).
# 2026-04-28 09:33:39,342 - INFO - Fetched data for TORNTPHARM (2477 rows).
# 2026-04-28 09:33:39,833 - INFO - Fetched data for TORNTPOWER (2477 rows).
# 2026-04-28 09:33:40,319 - INFO - Fetched data for TARIL (2477 rows).
# 2026-04-28 09:33:40,811 - INFO - Fetched data for TRENT (2477 rows).
# 2026-04-28 09:33:41,301 - INFO - Fetched data for TRIDENT (2477 rows).
# 2026-04-28 09:33:41,883 - INFO - Fetched data for TRIVENI (2477 rows).
# 2026-04-28 09:33:42,374 - INFO - Fetched data for TRITURBINE (2477 rows).
# 2026-04-28 09:33:42,846 - INFO - Fetched data for TIINDIA (2102 rows).
# 2026-04-28 09:33:43,343 - INFO - Fetched data for UCOBANK (2477 rows).
# 2026-04-28 09:33:43,827 - INFO - Fetched data for UNOMINDA (2477 rows).
# 2026-04-28 09:33:44,323 - INFO - Fetched data for UPL (2477 rows).
# 2026-04-28 09:33:44,778 - INFO - Fetched data for UTIAMC (1375 rows).
# 2026-04-28 09:33:45,288 - INFO - Fetched data for ULTRACEMCO (2477 rows).
# 2026-04-28 09:33:45,817 - INFO - Fetched data for UNIONBANK (2477 rows).
# 2026-04-28 09:33:46,303 - INFO - Fetched data for UBL (2477 rows).
# 2026-04-28 09:33:46,809 - INFO - Fetched data for UNITDSPR (2477 rows).
# 2026-04-28 09:33:47,305 - INFO - Fetched data for USHAMART (2477 rows).
# 2026-04-28 09:33:47,795 - INFO - Fetched data for VGUARD (2477 rows).
# 2026-04-28 09:33:48,291 - INFO - Fetched data for DBREALTY (2477 rows).
# 2026-04-28 09:33:48,777 - INFO - Fetched data for VTL (2477 rows).
# 2026-04-28 09:33:49,296 - INFO - Fetched data for VBL (2347 rows).
# 2026-04-28 09:33:49,746 - INFO - Fetched data for MANYAVAR (1039 rows).
# 2026-04-28 09:33:50,269 - INFO - Fetched data for VEDL (2477 rows).
# 2026-04-28 09:33:50,781 - INFO - Fetched data for VIJAYA (1146 rows).
# 2026-04-28 09:33:51,218 - INFO - Fetched data for VMM (336 rows).
# 2026-04-28 09:33:51,743 - INFO - Fetched data for IDEA (2476 rows).
# 2026-04-28 09:33:52,238 - INFO - Fetched data for VOLTAS (2477 rows).
# 2026-04-28 09:33:52,661 - INFO - Fetched data for WAAREEENER (371 rows).
# 2026-04-28 09:33:53,244 - INFO - Fetched data for WELCORP (2477 rows).
# 2026-04-28 09:33:53,669 - INFO - Fetched data for WELSPUNLIV (587 rows).
# 2026-04-28 09:33:54,166 - INFO - Fetched data for WESTLIFE (1659 rows).
# 2026-04-28 09:33:54,657 - INFO - Fetched data for WHIRLPOOL (2477 rows).
# 2026-04-28 09:33:55,316 - INFO - Fetched data for WIPRO (2477 rows).
# 2026-04-28 09:33:55,915 - INFO - Fetched data for WOCKPHARMA (2477 rows).
# 2026-04-28 09:33:56,426 - INFO - Fetched data for YESBANK (2477 rows).
# 2026-04-28 09:33:56,883 - INFO - Fetched data for ZFCVINDIA (1009 rows).
# 2026-04-28 09:33:57,381 - INFO - Fetched data for ZEEL (2477 rows).
# 2026-04-28 09:33:57,873 - INFO - Fetched data for ZENTEC (2477 rows).
# 2026-04-28 09:33:58,375 - INFO - Fetched data for ZENSARTECH (2477 rows).
# 2026-04-28 09:33:58,871 - INFO - Fetched data for ZYDUSLIFE (2477 rows).
# 2026-04-28 09:33:59,367 - INFO - Fetched data for ECLERX (2477 rows).
#               Date    Close  Ticker
# 0       2019-09-19   317.65  360ONE
# 1       2019-09-20   333.50  360ONE
# 2       2019-09-23   350.15  360ONE
# 3       2019-09-24   367.65  360ONE
# 4       2019-09-25   351.25  360ONE
# ...            ...      ...     ...
# 1037949 2026-04-22  1499.50  ECLERX
# 1037950 2026-04-23  1484.50  ECLERX
# 1037951 2026-04-24  1468.00  ECLERX
# 1037952 2026-04-27  1479.30  ECLERX
# 1037953 2026-04-28  1465.20  ECLERX
#
# [1037954 rows x 3 columns]
# Failed tickers: ['DUMMYABFRL', 'DUMMYSIEMS', 'DUMMYRAYMN', 'SWANENERGY', 'TATAMOTORS']
# 📊 Created 41 rolling windows.
#
# 🔍 Processing window: 2022-06-01 → 2022-12-01
# rank df:          Ticker   Positive   Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE  50.806452  48.387097   8.130084  INE466L01038     249.0
# 1       3MINDIA  47.580645  52.419355  13.148699  INE470A01017     206.0
# 2      AARTIIND  55.645161  44.354839  -2.403133  INE769A01020     341.0
# 3         AAVAS  45.161290  54.838710  -8.645213  INE216P01012     380.0
# 4           ABB  54.032258  45.967742  17.737040  INE117A01022     168.0
# ..          ...        ...        ...        ...           ...       ...
# 445        ZEEL  51.612903  47.580645   8.982564  INE256A01028     241.0
# 446  ZENSARTECH  43.548387  55.645161 -25.549146  INE520A01027     432.0
# 447      ZENTEC  39.516129  59.677419  -1.742073  INE251B01027     336.0
# 448   ZFCVINDIA  49.193548  50.806452  29.115463  INE342J01019      92.0
# 449   ZYDUSLIFE  49.193548  50.806452   3.371768  INE010B01027     279.0
#
# [450 rows x 6 columns]
# ✅ Saved results to: Stocks\Nifty_500_2025_Apr_20_stocks_results\momentum_20220601_20221201.xlsx
#
# 🔍 Processing window: 2022-07-01 → 2023-01-01
# rank df:          Ticker   Positive   Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE  50.806452  47.580645  12.129137  INE466L01038     236.0
# 1       3MINDIA  43.548387  56.451613   3.052966  INE470A01017     327.0
# 2      AARTIIND  51.612903  47.580645  -5.276849  INE769A01020     380.0
# 3         AAVAS  45.161290  54.838710  -3.716898  INE216P01012     376.0
# 4           ABB  54.838710  45.161290  12.640936  INE117A01022     231.0
# ..          ...        ...        ...        ...           ...       ...
# 446        ZEEL